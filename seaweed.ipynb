# %% [markdown]
# <a href="https://colab.research.google.com/github/bantigueroselle731-tech/coastal-plants-yolov8/blob/bantigueroselle731-tech-seaweed/seaweed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow ultralytics

# %%
from roboflow import Roboflow
from ultralytics import YOLO

# %%
rf = Roboflow(api_key="0HvMnWQKHk6LANgEzBeq")

# %%
workspace = rf.workspace("ast326bit3agroup8-ipg1l")
# Out:
# loading Roboflow workspace...

# %%
projects = workspace.projects()
print(projects)
# Out:
# ['ast326bit3agroup8-ipg1l/coastal-plants-coral-reef', 'ast326bit3agroup8-ipg1l/coastal-plants-mangrove', 'ast326bit3agroup8-ipg1l/coastal-plants-seagrass', 'ast326bit3agroup8-ipg1l/coastal-plants-seaweed']

# %%
project = workspace.project("coastal-plants-seaweed")

dataset = project.version(7).download("yolov8")
# Out:
# loading Roboflow project...

# %%
from roboflow import Roboflow
from ultralytics import YOLO

# Re-defining dependencies to ensure 'dataset' is available
rf = Roboflow(api_key="0HvMnWQKHk6LANgEzBeq")
workspace = rf.workspace("ast326bit3agroup8-ipg1l")
project = workspace.project("coastal-plants-seaweed")
dataset = project.version(7).download("yolov8")

model = YOLO("yolov8n.pt")

model.train(
    data=dataset.location + "/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Ultralytics 8.4.32 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...
