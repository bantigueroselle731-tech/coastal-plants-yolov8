# %% [markdown]
# <a href="https://colab.research.google.com/github/bantigueroselle731-tech/coastal-plants-yolov8/blob/bantigueroselle731-tech-patch-1/coral-reef.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow ultralytics

# %%
from roboflow import Roboflow
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
rf = Roboflow(api_key="0HvMnWQKHk6LANgEzBeq")

# %%
workspace = rf.workspace("ast326bit3agroup8-ipg1l")
# Out:
# loading Roboflow workspace...

# %%
projects = workspace.projects()
print(projects)
# Out:
# ['ast326bit3agroup8-ipg1l/coastal-plants-coral-reef', 'ast326bit3agroup8-ipg1l/coastal-plants-mangrove', 'ast326bit3agroup8-ipg1l/coastal-plants-seagrass', 'ast326bit3agroup8-ipg1l/coastal-plants-seaweed']

# %%
project = workspace.project("coastal-plants-coral-reef")

dataset = project.version(5).download("yolov8")
# Out:
# loading Roboflow project...

# %%
model = YOLO("yolov8n.pt")

model.train(
    data=dataset.location + "/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# ...
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...
